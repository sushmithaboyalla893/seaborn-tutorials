# %% [markdown]
# <a href="https://colab.research.google.com/github/sushmithaboyalla893/seaborn-tutorials/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing packages
import seaborn
import matplotlib.pyplot as plt
#loading dataset using seaborn
df=seaborn.load_dataset("tips")
#df.head()
print(df.to_string)
seaborn.pairplot(df)
plt.show()
# Out:
# <bound method DataFrame.to_string of      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]>

# %%
import seaborn
import matplotlib.pyplot as plt
df=seaborn.load_dataset("tips")
seaborn.pairplot(df,hue='size')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
df=sns.load_dataset("tips")
sns.pairplot(df,diag_kind='kde')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.pairplot(df,kind='reg')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.pairplot(df,hue='sex', markers=["o", "s"])
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.pairplot(df,hue='sex', markers=["o", "s"])
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.pairplot(df,hue='sex', markers=["o", "s"])
plt.show()

# %%
g=sns.pairplot(df,hue='day')
g.fig.suptitle("Pairplot of Tips Dataset", y=1.02)
g.set(xticks=[], yticks=[])
plt.show()

# %%
g=sns.pairplot(df,hue='day')
g.fig.suptitle("Pairplot of Tips Dataset", y=1.02)
g.set(xticks=[], yticks=[])
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
df=sns.load_dataset("tips")
sns.pairplot(df, hue="size", palette="husl")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
df=sns.load_dataset("tips")
selected_vars=['total_bill', 'tip']
sns.pairplot(df, vars=selected_vars)
plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
